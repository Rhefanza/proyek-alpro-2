# %%
import google.generativeai as genai
import os
from dotenv import load_dotenv

load_dotenv()

api_key = os.getenv("GOOGLE_API_KEY")

if not api_key:
    print("Error: GOOGLE_API_KEY tidak ditemukan.")
    print("Pastikan file .env ada dan berisi GOOGLE_API_KEY=...")
else:
    try:
        genai.configure(api_key=api_key) 

        model = genai.GenerativeModel('gemini-2.5-flash')
       
        response = model.generate_content("how to get a good health")
        print(response.text)

    except Exception as e:
        print(f"Terjadi error: {e}")
# Out:
# Achieving good health is a holistic journey that involves nurturing your physical, mental, and emotional well-being. It's not about quick fixes, but rather consistent, sustainable habits.
#
# Here's a comprehensive guide to getting and maintaining good health:
#
# ### 1. **Prioritize Nutrition**
#
# *   **Eat a Balanced Diet:** Focus on whole, unprocessed foods.
#     *   **Fruits and Vegetables:** Aim for a variety of colors daily. They provide vitamins, minerals, and fiber.
#     *   **Lean Protein:** Include sources like chicken, fish, beans, lentils, tofu, eggs, and lean red meat (in moderation). Protein is essential for muscle repair and satiety.
#     *   **Whole Grains:** Choose oats, brown rice, quinoa, and whole-wheat bread over refined grains. They provide sustained energy and fiber.
#     *   **Healthy Fats:** Incorporate avocados, nuts, seeds, and olive oil. These are crucial for brain health, hormone production, and nutrient absorption.
# *   **Limit Processed Foods:** Reduce intake of sugary drinks, fast food, packaged snacks, and foods high in unhealthy trans and saturated fats, added sugars, and sodium.
# *   **Stay Hydrated:** Drink plenty of water throughout the day. Water is vital for every bodily function.
# *   **Practice Mindful Eating:** Pay attention to your body's hunger and fullness cues. Eat slowly and savor your meals.
#
# ### 2. **Engage in Regular Physical Activity**
#
# *   **Aim for Consistency:** The general recommendation is at least 150 minutes of moderate-intensity aerobic activity or 75 minutes of vigorous-intensity activity per week, plus strength training at least twice a week.
# *   **Mix It Up:**
#     *   **Aerobic Exercise:** Walking, jogging, swimming, cycling, dancing. Improves cardiovascular health.
#     *   **Strength Training:** Lifting weights, bodyweight exercises (push-ups, squats), resistance bands. Builds muscle mass and bone density.
#     *   **Flexibility and Balance:** Yoga, Pilates, stretching. Improves range of motion and prevents injuries.
# *   **Find Activities You Enjoy:** This makes it easier to stick with a routine.
# *   **Reduce Sedentary Time:** Take breaks to stand, stretch, or walk around if you have a desk job.
#
# ### 3. **Ensure Adequate Sleep**
#
# *   **Aim for 7-9 Hours:** Most adults need 7-9 hours of quality sleep per night.
# *   **Establish a Sleep Schedule:** Go to bed and wake up around the same time each day, even on weekends.
# *   **Create a Relaxing Bedtime Routine:** Avoid screens (phones, tablets, TVs) at least an hour before bed. Read a book, take a warm bath, or practice relaxation techniques.
# *   **Optimize Your Sleep Environment:** Make your bedroom dark, quiet, and cool.
# *   **Limit Caffeine and Alcohol:** Especially in the hours leading up to bedtime.
#
# ### 4. **Manage Stress Effectively**
#
# *   **Identify Stressors:** Recognize what triggers your stress.
# *   **Practice Relaxation Techniques:**
#     *   **Mindfulness and Meditation:** Even a few minutes a day can make a difference.
#     *   **Deep Breathing Exercises:** Calms the nervous system.
#     *   **Yoga or Tai Chi:** Combines physical movement with mental focus.
# *   **Engage in Hobbies:** Dedicate time to activities you enjoy.
# *   **Spend Time in Nature:** Research shows a positive impact on mental well-being.
# *   **Set Boundaries:** Learn to say no to commitments that overwhelm you.
# *   **Seek Support:** Talk to friends, family, or a therapist if stress feels unmanageable.
#
# ### 5. **Prioritize Mental and Emotional Well-being**
#
# *   **Foster Positive Relationships:** Connect with loved ones and build a strong support system.
# *   **Practice Gratitude:** Regularly reflect on things you're thankful for.
# *   **Challenge Negative Thoughts:** Recognize and reframe unhelpful thought patterns.
# *   **Seek Professional Help:** Don't hesitate to consult a therapist or counselor if you're struggling with anxiety, depression, or other mental health concerns.
# *   **Learn New Things:** Keep your brain engaged and challenged.
#
# ### 6. **Avoid Harmful Substances**
#
# *   **Stop Smoking:** Smoking is detrimental to almost every organ in your body.
# *   **Limit Alcohol Consumption:** If you drink, do so in moderation.
# *   **Avoid Illicit Drugs:** They have serious health consequences.
#
# ### 7. **Regular Medical Check-ups and Preventive Care**
#
# *   **Visit Your Doctor Regularly:** Schedule annual physicals and screenings (blood pressure, cholesterol, blood sugar, cancer screenings as recommended).
# *   **Stay Up-to-Date on Vaccinations:** Flu shots, tetanus boosters, etc.
# *   **Practice Good Hygiene:** Wash hands frequently to prevent the spread of illness.
# *   **Listen to Your Body:** Don't ignore persistent symptoms; seek medical advice when needed.
#
# ### Key Principles for Success:
#
# *   **Consistency is Key:** Small, consistent efforts yield the best long-term results.
# *   **Start Small:** Don't try to overhaul everything at once. Choose one or two areas to focus on first and gradually build from there.
# *   **Be Patient and Kind to Yourself:** There will be ups and downs. Don't let setbacks derail your entire journey.
# *   **Seek Professional Guidance:** Consult with doctors, registered dietitians, personal trainers, or therapists for personalized advice and support.
# *   **Listen to Your Body:** Everyone is different. What works for one person might not work for another. Adjust your habits based on how you feel.
#
# Good health is a continuous process of learning, adapting, and making conscious choices that support your well-being.
